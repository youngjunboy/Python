# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1. 아래와 같이 타이타닉에 탑승한 승객들의 나이를 x 축에 표기하고, y 축은 승객의 수를 표현할 수 있도록 그래프를 코딩하세요.

# %%
titanic = pd.read_csv("data/titanic.csv")
titanic["age"] = pd.to_numeric(titanic["age"], errors="coerce")

# %%
plt.hist(titanic["age"],color = "red")
# Out:
# (array([ 72.,  62., 274., 250., 161., 108.,  65.,  41.,  10.,   3.]),
#  array([ 0.1667 ,  8.15003, 16.13336, 24.11669, 32.10002, 40.08335,
#         48.06668, 56.05001, 64.03334, 72.01667, 80.     ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 2. 아래 데이터를 입력하고 보이는 그래프를 표출하는 코딩을 하세요.

# %%
heights = [137,140,142,145,147,150,152,155,157,160]
f_weights = [28.5,30.8,32.6,34.9,36.4,39,40.8,43.1,44.9,47.2]
m_weights = [34.9,38.1,33.5,35.8,46.7,42.8,43.1,45.8,50.8,58.9]

plt.plot(heights, f_weights, marker = "*",label="Female")
plt.plot(heights, m_weights, marker = "*",label="Male")
plt.legend()
plt.xlabel("height (cm)")
plt.ylabel("weight (kg)")
# Out:
# Text(0, 0.5, 'weight (kg)')

# %% [markdown]
# # 3. numpy를 활용하여 random 숫자 100개를 생성하고, 이를 활용하여 아래와 같은 그래프를 그리는 코드를 쓰세요.

# %%
np.random.randn(100)
# Out:
# array([-0.9553164 ,  0.88271226,  0.4889057 ,  0.20100574, -0.16109407,
#         1.28568963,  1.61571412,  2.45606231, -1.11573919,  0.49335505,
#         0.2358447 ,  1.21678532,  0.10084266,  1.3963005 ,  0.265594  ,
#        -0.12884387,  1.10906188, -0.19391751, -0.22823556, -1.37851836,
#        -0.85030605,  0.29903787, -0.0100142 , -0.83736947, -0.47504041,
#         0.66666832,  2.09381695, -0.51460137, -0.28061548,  1.5289267 ,
#        -0.75413275, -0.2973094 , -0.20443063,  0.72432227,  1.19887073,
#        -0.91049896, -0.22207501,  0.30954882, -0.77464402,  0.71461941,
#        -2.65140836,  0.42466802,  0.3524382 , -0.94136019, -0.23273229,
#        -0.35475221, -1.03890264, -0.44994767, -0.54856748,  0.30169461,
#         0.10729254,  1.246648  , -0.56150913,  0.84020525,  0.39997216,
#         1.7900687 ,  0.9141084 ,  1.07059434,  0.49998372,  0.82734364,
#         1.06200021, -0.15492085, -0.5627308 ,  0.07022909, -0.5259302 ,
# ...

# %% [markdown]
# # 4. 아래와 같이 titanic pclass 별로 탑승자 연령분포도를 그리세요.

# %%
first_class = titanic[titanic["pclass"]==1]["age"]
second_class= titanic[titanic["pclass"]==2]["age"]
third_class=titanic[titanic["pclass"]==3]["age"]

plt.figure(figsize = (10, 4))
ax = plt.subplot(1,3,1)
plt.hist(first_class, label = "1st Class", color="#f1c40f", bins=20)
plt.title("1st Class")

plt.subplot(1,3,2, sharey = ax)
plt.hist(second_class, label = "2nd Class", color="#3498db", bins=20)
plt.title("2nd Class")

plt.subplot(1,3,3, sharey = ax)
plt.hist(third_class, label = "3rd Class", color="#e74c3c", bins=20)
plt.title("3rd Class")
# Out:
# Text(0.5, 1.0, '3rd Class')

# %% [markdown]
# # 5. 아래와 같이 하루 일정표를 pie 그래프로 나타내세요

# %% [markdown]
# # 6. kc_house_data.csv 데이터를 활용하여 각 주택의 거실의 크기에 따른 부지 크기를 함께 나타내도록 그래프를 그리세요.

# %%
house = pd.read_csv("data/kc_house_data.csv")
house.plot.scatter("sqft_living","sqft_lot")

# %% [markdown]
# # 7. nuforc_reports.csv 데이터를 활용하여 월별 UFO 출몰 빈도를 나타내는 그래프를 그리세요.

# %%
ufos = pd.read_csv("data/nuforc_reports.csv",parse_dates=["date_time","posted"])
ufos["month"]=ufos["date_time"].dt.month
ufos["year"]=ufos["date_time"].dt.year
sightings = ufos.month.value_counts().sort_index()
sightings.plot(
        kind="bar",
        title="UFO Month",
        xlabel="month")

# %% [markdown]
# # 8. Salaries.csv 데이터에서 앞에서부터 7명의 기본급, 초과근무수당, 기타수당을 한 그래프에 나타내도록 코딩하세요.

# %%
Salaries = pd.read_csv("data/Salaries.csv")
Salaries[["BasePay","OvertimePay","OtherPay"]].head(7)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_6084\4079101427.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   Salaries = pd.read_csv("data/Salaries.csv")
#      BasePay OvertimePay   OtherPay
# 0  167411.18         0.0  400184.25
# 1  155966.02   245131.88  137811.38
# 2  212739.13   106088.18    16452.6
# 3    77916.0    56120.71   198306.9
# 4   134401.6      9737.0  182234.59
# 5   118602.0      8601.0  189082.74
# 6   92492.01     89062.9  134426.14

# %% [markdown]
# # 9. Salaries.csv 데이터를 활용하여 초과근무수당이 가장 높은 순서대로 TOP 10 에 해당하는 데이터가 그래프로 표출되도록 코딩하세요.

# %%
Salaries = pd.read_csv("data/Salaries.csv")
Salaries["OvertimePay"].value_counts().head(10).plot()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_6084\3321860628.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   Salaries = pd.read_csv("data/Salaries.csv")
# <AxesSubplot: >

# %% [markdown]
# # 10. BOXPLOT 그래프를 활용하여 Salaries 데이터의 기본급과 초과근무수당과 기타수당의 분포 그래프를 그리고, 해당 그래프에 대한 설명을 하세요.

# %%
Salaries["BasePay"] = pd.to_numeric(Salaries["BasePay"], errors="coerce").fillna(0)
Salaries["OvertimePay"] = pd.to_numeric(Salaries["OvertimePay"], errors="coerce").fillna(0)
Salaries["OtherPay"] = pd.to_numeric(Salaries["OtherPay"], errors="coerce").fillna(0)
Salaries[["BasePay","OvertimePay","OtherPay"]].plot(kind="box")

# 박스가 있는 곳이 평균이며 그 외 동그라미들은 미미한 데이터 들이다.
# Out:
# <AxesSubplot: >
