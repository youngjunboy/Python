# %%
import csv

f = open('temp2013.csv')
data = csv.reader(f)

# %%
import csv

f = open('temp2013.csv')
data = csv.reader(f)

header = next(data)

# print(header)

for row in data:
    print(row)

f.close()
# Out:
# ['\t\t108', '서울', 'Jan-13', '-3.4', '0.3', '11.5', '2013-01-31', '-6.6', '-16.4', '2013-01-03']
# ['\t\t108', '서울', 'Feb-13', '-1.2', '2.8', '13.9', '2013-02-28', '-4.9', '-15.8', '2013-02-08']
# ['\t\t108', '서울', 'Mar-13', '5.1', '10.8', '23.8', '2013-03-09', '0.7', '-4.4', '2013-03-02']
# ['\t\t108', '서울', 'Apr-13', '10', '15', '21.6', '2013-04-28', '5.7', '1.3', '2013-04-10']
# ['\t\t108', '서울', 'May-13', '18.2', '23.6', '31.8', '2013-05-25', '13.7', '7.9', '2013-05-06']
# ['\t\t108', '서울', 'Jun-13', '24.4', '29.2', '32.6', '2013-06-29', '20.5', '16.3', '2013-06-02']
# ['\t\t108', '서울', 'Jul-13', '25.5', '28.3', '31.3', '2013-07-01', '23.4', '20.5', '2013-07-03']
# ['\t\t108', '서울', 'Aug-13', '27.7', '31.1', '33.9', '2013-08-21', '24.8', '21.1', '2013-08-31']
# ['\t\t108', '서울', 'Sep-13', '21.8', '25.9', '31.1', '2013-09-18', '18', '10.9', '2013-09-27']
# ['\t\t108', '서울', 'Oct-13', '15.8', '21.2', '28.1', '2013-10-05', '10.9', '4.3', '2013-10-26']
# ...

# %%
import csv

f = open('temp2013.csv')
data = csv.reader(f)

header = next(data)

# print(header)

for row in data:
    print(row)

f.close()
# Out:
# ['\t\t108', '서울', 'Jan-13', '-3.4', '0.3', '11.5', '2013-01-31', '-6.6', '-16.4', '2013-01-03']
# ['\t\t108', '서울', 'Feb-13', '-1.2', '2.8', '13.9', '2013-02-28', '-4.9', '-15.8', '2013-02-08']
# ['\t\t108', '서울', 'Mar-13', '5.1', '10.8', '23.8', '2013-03-09', '0.7', '-4.4', '2013-03-02']
# ['\t\t108', '서울', 'Apr-13', '10', '15', '21.6', '2013-04-28', '5.7', '1.3', '2013-04-10']
# ['\t\t108', '서울', 'May-13', '18.2', '23.6', '31.8', '2013-05-25', '13.7', '7.9', '2013-05-06']
# ['\t\t108', '서울', 'Jun-13', '24.4', '29.2', '32.6', '2013-06-29', '20.5', '16.3', '2013-06-02']
# ['\t\t108', '서울', 'Jul-13', '25.5', '28.3', '31.3', '2013-07-01', '23.4', '20.5', '2013-07-03']
# ['\t\t108', '서울', 'Aug-13', '27.7', '31.1', '33.9', '2013-08-21', '24.8', '21.1', '2013-08-31']
# ['\t\t108', '서울', 'Sep-13', '21.8', '25.9', '31.1', '2013-09-18', '18', '10.9', '2013-09-27']
# ['\t\t108', '서울', 'Oct-13', '15.8', '21.2', '28.1', '2013-10-05', '10.9', '4.3', '2013-10-26']
# ...

# %%
import csv

f = open('temp2013.csv')
data = csv.reader(f)
header = next(data)

for row in data:
    row[-2] = float(row[-2])
    print(row)

f.close()
# Out:
# ['\t\t108', '서울', 'Jan-13', '-3.4', '0.3', '11.5', '2013-01-31', '-6.6', -16.4, '2013-01-03']
# ['\t\t108', '서울', 'Feb-13', '-1.2', '2.8', '13.9', '2013-02-28', '-4.9', -15.8, '2013-02-08']
# ['\t\t108', '서울', 'Mar-13', '5.1', '10.8', '23.8', '2013-03-09', '0.7', -4.4, '2013-03-02']
# ['\t\t108', '서울', 'Apr-13', '10', '15', '21.6', '2013-04-28', '5.7', 1.3, '2013-04-10']
# ['\t\t108', '서울', 'May-13', '18.2', '23.6', '31.8', '2013-05-25', '13.7', 7.9, '2013-05-06']
# ['\t\t108', '서울', 'Jun-13', '24.4', '29.2', '32.6', '2013-06-29', '20.5', 16.3, '2013-06-02']
# ['\t\t108', '서울', 'Jul-13', '25.5', '28.3', '31.3', '2013-07-01', '23.4', 20.5, '2013-07-03']
# ['\t\t108', '서울', 'Aug-13', '27.7', '31.1', '33.9', '2013-08-21', '24.8', 21.1, '2013-08-31']
# ['\t\t108', '서울', 'Sep-13', '21.8', '25.9', '31.1', '2013-09-18', '18', 10.9, '2013-09-27']
# ['\t\t108', '서울', 'Oct-13', '15.8', '21.2', '28.1', '2013-10-05', '10.9', 4.3, '2013-10-26']
# ...

# %%
import matplotlib.pyplot as plt

plt.title('legend')
plt.plot([10,20,30,40], label='asc')
plt.plot([40,30,20,10], label='desc')
plt.legend(loc='center left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('Draw Graph')
plt.plot([10,20,30,40], label='asc')
plt.plot([40,30,20,10], label='desc')
plt.legend()
# plt.grid()
#plt.grid(color='gray')
plt.grid(color='red', dashes=(10,10))
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('marker')
plt.plot([10,20,30,40],'rs', label='circle')
plt.plot([40,30,20,10],'g*', label='triangle up')
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
f = open('temp2013.csv')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[-1] != '':
        result.append(float(row[5]))
    
plt.plot(result, 'pink')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
s = 'hong young jun'
print(s.split())
# Out:
# ['hong', 'young', 'jun']

# %%
date = '1907-10-01'
print(date.split('-'))
# Out:
# ['1907', '10', '01']

# %%
date = '1907-10-01'
print(date.split('-')[0])
print(date.split('-')[1])
print(date.split('-')[2])
print(date.split("-")[0])
# Out:
# 1907
# 10
# 01
# 1907

# %%
import csv
import matplotlib.pyplot as plt

f = open("temp2013.csv")
data = csv.reader(f)
next(data)
         
result = []
    
for row in data:
    if row[5] != "":
        if row[6].split('-')[1]=="08":
            result.append(float(row[5]))
plt.plot(result, 'hotpink')
plt.show()
f.close()

# %%
import csv
import matplotlib.pyplot as plt

f = open("temp1904.csv")
data = csv.reader(f)
next(data)

high = []
low = []

for row in data:
    if row[-1] != "" and row[-2] != "":
        if 2006<= int(row[0].split("-")[0]):
            if row[0].split("-")[1] == "10" and row[0].split("-")[2] == "30":
                high.append(float(row[-1]))
                low.append(float(row[-2]))
plt.rc("font", family = "Malgun Gothic")
plt.rcParams["axes.unicode_minus"] = False
plt.title("내 생년 이후의 생일의 기온 그래프")
plt.plot(high,"hotpink" ,label = "high")
plt.plot(low,"skyblue" ,label = "low")
plt.legend(loc="upper left")
plt.show()
f.close()

# %%
import csv
import matplotlib.pyplot as plt

f = open("subway202306.csv")
data = csv.reader(f)

header1 = next(data)
header2 = next(data)

for row in data:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10888/3103972339.py in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 f = open("subway202306.csv")
#       5 data = csv.reader(f)
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: 'subway202306.csv'

# %%
import csv
import matplotlib.pyplot as plt

f = open("subway202306.csv")
data = csv.reader(f)

header1 = next(data)
header2 = next(data)

for row in data:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10888/3103972339.py in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 f = open("subway202306.csv")
#       5 data = csv.reader(f)
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: 'subway202306.csv'
