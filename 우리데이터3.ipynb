# %%
# !pip install plotly
# !pip install cufflinks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings

# %matplotlib inline

# %%
SKD = pd.read_csv("data/0급-기밀파일.csv", encoding="cp949")
SKD.head()
# Out:
#                      타임스탬프     교복 단어 성별   학년 교복 착용           입는 이유  안 입는 이유  \
# 0  2023. 10. 26 오후 2:08:13        학생  남  2학년     네   학교에서 입으라고 합니다    불편합니다
# 1  2023. 10. 26 오후 2:13:04       불편함  남  3학년   아니오             NaN  사복이 편해요
# 2  2023. 10. 26 오후 2:15:17       불편함  남  3학년   아니오             NaN    불편합니다
# 3  2023. 10. 26 오후 2:15:20        셔츠  남  3학년     네  마땅히 입을 옷이 없습니다      NaN
# 4  2023. 10. 26 오후 2:15:45  옷안사도돼서개꿀  남  3학년   아니오             NaN    귀찮습니다
#
#   디자인이 별로인 것          교복 필요성  \
# 0         바지     필요하다고 생각합니다
# 1         조끼  필요하지 않다고 생각합니다
# 2        NaN     필요하다고 생각합니다
# 3        NaN     필요하다고 생각합니다
# 4         마이     필요하다고 생각합니다
#
#                                                필요 이유         불필요 이유 입기 싫은 요일  \
# 0                                       늙으면 입을 수 없어서            NaN        화
# 1                                                NaN  입는 목적을 잘 모르겠은        금
# 2                                 소외되는 학생이 있을 수 있으니까            NaN        화
# ...

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
sns.countplot(data=SKD, x="사복 착용", hue="학년")
# Out:
# <Axes: xlabel='사복 착용', ylabel='count'>

# %%
SKD1 = pd.read_csv("data/0급-기밀파일-1.csv", encoding="cp949")
SKD1.head(1)
# Out:
#                      타임스탬프 교복 단어 성별   학년 교복 착용          입는 이유 안 입는 이유  \
# 0  2023. 10. 26 오후 2:08:13    학생  남  2학년     네  학교에서 입으라고 합니다   불편합니다
#
#   디자인이 별로인 것       교복 필요성         필요 이유  ... 학과 만족여부 전공 선호도 소셜미디어 사용시간  \
# 0         바지  필요하다고 생각합니다  늙으면 입을 수 없어서  ...       O      5    1시간-2시간
#
#      등교시간     하교시간   하교후 가는 곳 학업 스트레스 친구관계 알바 방과후 여부
# 0  10-30분  18시 이후!  학원 또는 방과후      좋음   나쁨  X      O
#
# [1 rows x 30 columns]

# %%
sns.countplot(data=SKD1, x="입기 싫은 요일", hue="하교후 가는 곳")
# Out:
# <Axes: xlabel='입기 싫은 요일', ylabel='count'>

# %%
sns.histplot(data=SKD1, x="교복 착용", hue="학업 스트레스")
# Out:
# <Axes: xlabel='교복 착용', ylabel='Count'>

# %%
SKD1["학과"].value_counts()
# Out:
# 소프트웨어개발과    97
# 스마트웹콘텐츠과    55
# 창업마케팅과      42
# 부사관과        34
# 금융경영과       28
# 뷰티디자인과       5
# 회계정보과        4
# Name: 학과, dtype: int64

# %%
sns.countplot(data=SKD1, x="교복 착용", hue="학과")
# Out:
# <Axes: xlabel='교복 착용', ylabel='count'>

# %%
sns.histplot(data=SKD1, x="교복 착용", hue="개인공부시간")
# Out:
# <Axes: xlabel='교복 착용', ylabel='Count'>
